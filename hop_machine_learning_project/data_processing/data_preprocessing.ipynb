# %%
import pandas as pd
import os
from typing import Union, List, Dict, Tuple, Optional
from collections import Counter

# %%
def read_excel_sheets(file_path: str,
                     sheets: Union[str, List[str]] = None,
                     na_values: List[str] = None,
                     dtype: Dict[str, str] = None) -> Union[pd.DataFrame, Dict[str, pd.DataFrame]]:
   '''
   Reads Excel sheets into Pandas DataFrame(s).


   Args:
       file_path (str): Path to the Excel file.
       sheets (Union[str, List[str]], optional): Sheet name or list of sheet names to load. If None, loads the first sheet.
       na_values (List[str], optional): Additional strings to recognize as NA/NaN.
       dtype (Dict[str, str], optional): Column data types.


   Returns:
       Union[pd.DataFrame, Dict[str, pd.DataFrame]]: DataFrame for one sheet, or dict of DataFrames if multiple sheets.
   '''
   if not os.path.isfile(file_path):
       raise FileNotFoundError(f'File not found: {file_path}')


   print(f'Reading file: {file_path}')


   df = pd.read_excel(
       file_path,
       sheet_name=sheets,
       na_values=na_values,
       dtype=dtype
   )


   return df

# %%
def explore_df(df: pd.DataFrame) -> None:
   '''
   Quickly explore a DataFrame.
   '''
   print('Shape:', df.shape)
   print('\nColumns:', df.columns.tolist())
   print('\nFirst 5 rows:')
   print(df.head())
   print('\n10 Random rows:')
   print(df.sample(10))
   print('\nInfo:')
   print(df.info())
   print('\nDescribe:')
   print(df.describe(include='all'))
   print('\nMissing values per column:')
   print(df.isnull().sum())

# %%
def handle_ratios(value) -> Tuple[Optional[float], Optional[float], Optional[float], Optional[float]]:
    '''
    Parses a simple ratio string like '2:1' and returns:
    - low: the smaller of the two numbers
    - high: the larger of the two numbers
    - midpoint: arithmetic mean of the two values
    - ratio: first number divided by the second

    Returns (None, None, None, None) for invalid input (e.g., wrong format, division by zero).
    '''
    try:
        # Convert the input to string, strip whitespace, and split by ':'
        parts = list(map(float, str(value).strip().split(':')))
        
        # Ensure the ratio has exactly two numeric parts and avoid division by zero
        if len(parts) != 2 or parts[1] == 0:
            return None, None, None, None
        
        # Get the smaller and larger of the two values
        low = min(parts)
        high = max(parts)

        # Calculate the midpoint (arithmetic mean of the two numbers)
        midpoint = sum(parts) / 2

        # Compute the directional ratio using original order (a / b)
        ratio = parts[0] / parts[1]

        # Return all four computed values
        return low, high, midpoint, ratio

    # Catch any unexpected errors (e.g., non-numeric input)
    except Exception:
        return None, None, None, None

# %%
def extract_list_from_string(raw_string):
    '''
    Converts a comma-separated string to a list of stripped strings.
    Handles missing or non-string inputs safely.
    '''
    if not isinstance(raw_string, str):
        return []
    return [item.strip() for item in raw_string.split(',') if item.strip()]

# %% [markdown]
# Currently, beer_styles isn't being entirely extracted correctly by ScrapStorm.

# %%
# === Load and Combine Excel Sheets ===
sheets_to_load = [
    'beer_maverick_rows_1_100'
]

# Load specified sheets from Excel file.

hop_df_multi = read_excel_sheets('beer_maverick_data.xlsx', sheets=sheets_to_load)

# Display basic info about each loaded sheet.
for sheet_name, df in hop_df_multi.items():
    print(f'Loaded {sheet_name}: {df.shape}')

# Concatenate all sheets into a single df.
hop_df = pd.concat(hop_df_multi.values(), ignore_index=True)

# Initial exploration before any parsing.
print('Before parsing columns:')
explore_df(hop_df)
# Out:
# Reading file: beer_maverick_data.xlsx
# Loaded beer_maverick_rows_1_100: (100, 14)
# Before parsing columns:
# Shape: (100, 14)
#
# Columns: ['name', 'purpose', 'alpha_acid_avg', 'beta_acid_avg', 'alpha_beta_ratio', 'hsi', 'cohumulone_%_of_alpha', 'total_oils_avg', 'myrcene', 'humulene', 'caryophyllene', 'farnesene', 'tags', 'beer_styles']
#
# First 5 rows:
#       name purpose  alpha_acid_avg  beta_acid_avg alpha_beta_ratio    hsi  \
# 0      NaN     NaN             NaN            NaN              NaN    NaN
# 1    Astra    Dual             8.5            5.0              2:1    NaN
# 2  Eclipse    Dual            17.4            7.5              2:1    NaN
# 3     Ella    Dual            16.3            5.9              3:1    NaN
# 4   Enigma   Aroma            16.5            5.8              3:1  0.295
#
#   cohumulone_%_of_alpha  total_oils_avg  myrcene  humulene  caryophyllene  \
# 0                   NaN             NaN      NaN       NaN            NaN
# 1               27% avg             2.0      NaN       7.0            2.5
# 2               35% avg             2.3     42.0       1.0            9.0
# 3             36.5% avg             2.9     42.0      18.5           11.5
# 4               40% avg             2.4     26.5      15.5            7.0
#
#    farnesene                                               tags  \
# 0        NaN                                                NaN
# 1        NaN  tropical_fruit,sweet,peach,white_wine,melon,gr...
# 2        0.5                               citrus,pine,mandarin
# 3       13.0  floral,spicy,grapefruit,tropical_fruit,noble,a...
# 4       10.5  tropical_fruit,berry,stone_fruit,raspberry,red...
#
#                           beer_styles
# 0                                 NaN
# 1       Ale,Pale Ale,IPA,Lager,Saison
# 2  IPA,Pale Ale,NEIPA,Lager,Wheat Ale
# 3        Pale Ale,Stout,Lager,Pilsner
# 4                        IPA,Pale Ale
#
# 10 Random rows:
#         name    purpose  alpha_acid_avg  beta_acid_avg alpha_beta_ratio  hsi  \
# 28   Bohemie      Aroma             6.5            7.5              1:1  NaN
# 80     Tango       Dual             9.3            8.8              1:1  NaN
# 88       NaN        NaN             NaN            NaN              NaN  NaN
# 35  Premiant  Bittering             8.0            5.0              2:1  NaN
# 84       NaN        NaN             NaN            NaN              NaN  NaN
# 67    Merkur       Dual            14.1            5.9              3:1  NaN
# 41    Aramis      Aroma             7.0            4.3              2:1  NaN
# 33    Kazbek      Aroma             6.5            5.0              1:1  NaN
# 70      Opal       Dual             9.5            4.5              2:1  NaN
# 75    Saphir      Aroma             3.3            5.5              1:1  NaN
#
#    cohumulone_%_of_alpha  total_oils_avg  myrcene  humulene  caryophyllene  \
# 28             24.5% avg             1.3     37.5      20.0            8.5
# 80               22% avg             3.2      NaN       NaN            NaN
# 88                   NaN             NaN      NaN       NaN            NaN
# 35             20.5% avg             1.5     42.5      30.0           10.5
# 84                   NaN             NaN      NaN       NaN            NaN
# 67             18.5% avg             2.5     47.5      30.0            9.0
# 41               31% avg             1.4     39.5      20.5            5.0
# 33             37.5% avg             1.4     47.5      27.5           12.5
# 70             23.5% avg             1.1     32.5      40.0           11.5
# 75             14.5% avg             1.1     32.5      25.0           11.5
#
#     farnesene                                               tags  \
# 28        2.0                         herbal,floral,citrus,spicy
# 80        NaN               passion_fruit,pineapple,spicy,citrus
# 88        NaN                                                NaN
# 35        2.0                                            neutral
# 84        NaN                                                NaN
# 67        0.5                 sugar,pineapple,mint,citrus,earthy
# 41        3.0  green,herbal,spicy,citrus,grassy,black_pepper,...
# 33        0.5                                        spicy,lemon
# 70        0.5      black_pepper,citrus,spicy,floral,herbal,anise
# 75        0.5                      spicy,fruity,floral,tangerine
#
#                                           beer_styles
# 28                                                NaN
# 80                                                NaN
# 88                                                NaN
# 35                                  Pilsner,Ale,Lager
# 84                                                NaN
# 67                IPA,Lager,Belgian Ale,Pilsner,Stout
# 41  Saison,Belgian Ale,French Ale,Trappist,Porter,...
# 33               Lagers,Pale Ales,Wheats,Belgian Ales
# 70  Belgian Ale,Hefeweizen,Helles,Lager,Pilsner,Wh...
# 75             Pilsner,German Lager,Belgian Ale,Wheat
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   92 non-null     object
#  1   purpose                92 non-null     object
#  2   alpha_acid_avg         92 non-null     float64
#  3   beta_acid_avg          88 non-null     float64
#  4   alpha_beta_ratio       84 non-null     object
#  5   hsi                    12 non-null     object
#  6   cohumulone_%_of_alpha  84 non-null     object
#  7   total_oils_avg         87 non-null     float64
#  8   myrcene                72 non-null     float64
#  9   humulene               70 non-null     float64
#  10  caryophyllene          69 non-null     float64
#  11  farnesene              68 non-null     float64
#  12  tags                   88 non-null     object
#  13  beer_styles            77 non-null     object
# dtypes: float64(7), object(7)
# memory usage: 11.1+ KB
# None
#
# Describe:
#          name purpose  alpha_acid_avg  beta_acid_avg alpha_beta_ratio    hsi  \
# count      92      92       92.000000       88.00000               84     12
# unique     92       3             NaN            NaN                5     12
# top     Astra   Aroma             NaN            NaN              2:1  0.295
# freq        1      47             NaN            NaN               40      1
# mean      NaN     NaN        8.761957        5.67500              NaN    NaN
# std       NaN     NaN        4.372085        1.63758              NaN    NaN
# min       NaN     NaN        2.200000        2.90000              NaN    NaN
# 25%       NaN     NaN        5.775000        4.50000              NaN    NaN
# 50%       NaN     NaN        7.500000        5.50000              NaN    NaN
# 75%       NaN     NaN       11.625000        6.57500              NaN    NaN
# max       NaN     NaN       20.500000       12.50000              NaN    NaN
#
#        cohumulone_%_of_alpha  total_oils_avg    myrcene   humulene  \
# count                     84       87.000000  72.000000  70.000000
# unique                    46             NaN        NaN        NaN
# top                37.5% avg             NaN        NaN        NaN
# freq                       5             NaN        NaN        NaN
# mean                     NaN        1.539080  40.944444  20.478571
# std                      NaN        0.719715  12.851962  12.832939
# min                      NaN        0.600000   7.000000   1.000000
# 25%                      NaN        1.050000  32.500000  12.125000
# 50%                      NaN        1.400000  39.750000  20.000000
# 75%                      NaN        1.800000  47.750000  29.625000
# max                      NaN        4.500000  70.000000  55.500000
#
#         caryophyllene  farnesene  \
# count       69.000000  68.000000
# unique            NaN        NaN
# top               NaN        NaN
# freq              NaN        NaN
# mean         8.753623   3.136765
# std          4.522512   5.372564
# min          1.000000   0.500000
# 25%          6.500000   0.500000
# 50%          9.000000   0.500000
# 75%         10.500000   2.250000
# max         27.500000  25.000000
#
#                                                      tags beer_styles
# count                                                  88          77
# unique                                                 88          71
# top     tropical_fruit,sweet,peach,white_wine,melon,gr...   Ale,Lager
# freq                                                    1           4
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
# Missing values per column:
# name                      8
# purpose                   8
# alpha_acid_avg            8
# beta_acid_avg            12
# alpha_beta_ratio         16
# hsi                      88
# cohumulone_%_of_alpha    16
# total_oils_avg           13
# myrcene                  28
# humulene                 30
# caryophyllene            31
# farnesene                32
# tags                     12
# beer_styles              23
# dtype: int64

# %%
# === Clean and Parse Data ===
# Replace 'ratio' with the midpoint of the two numbers in the ratio string.
# For example, '2:1' becomes 1.5 = (2 + 1) / 2
hop_df['alpha_beta_ratio'] = hop_df['alpha_beta_ratio'].apply(lambda x: handle_ratios(x)[2])

# Loop through the columns 'beer_styles' & 'tags', apply the extract_list_from_string function.
# This converts each comma-separated string (e.g., 'IPA,Lager') into a list (e.g., ['IPA', 'Lager']).
# The original string values in these columns will be overwritten with their corresponding lists.
for col in ['beer_styles', 'tags']:
    hop_df[col] = hop_df[col].apply(extract_list_from_string)

    # Count and print all unique items in the column
    all_items = [item for sublist in hop_df[col] for item in sublist]
    counts = Counter(all_items)

    print(f'\nUnique values and counts for column: {col}')
    for item, count in counts.most_common():
        print(f'  {item}: {count}')

# Final exploration after parsing.
print('After parsing columns:')
explore_df(hop_df)

# Write out processed df to parquet file (preserves list structure, compressed).
parquet_path = 'processed_hop_data.parquet'
hop_df.to_parquet(parquet_path, index=False)
print(f'Data exported to: {parquet_path} (Parquet format)')

# Write out processed df to CSV.
csv_path = 'processed_hop_data.csv'
hop_df.to_csv(csv_path, index=False)
print(f'Data exported to: {csv_path} (CSV format — lists saved as strings)')
# Out:
# Unique values and counts for column: beer_styles
#   Lager: 37
#   IPA: 33
#   Pale Ale: 29
#   Pilsner: 27
#   Belgian Ale: 17
#   Saison: 14
#   Ale: 9
#   Wheat: 9
#   Stout: 7
#   Kolsch: 6
#   NEIPA: 5
#   Bock: 5
#   Porter: 5
#   German Ale: 5
#   Altbier: 5
#   Wheat Beer: 4
#   Helles: 4
#   American Ale: 3
#   Bitter: 3
#   ESB: 3
#   Wheats: 3
#   Golden Ale: 3
#   English Ale: 3
#   German Lager: 3
#   Hefeweizen: 3
#   Fruit Beers: 2
#   American Pale Ale: 2
#   Amber Ale: 2
#   Red Ale: 2
#   Lagers: 2
#   Belgian Ales: 2
#   French Ale: 2
#   Blonde Ale: 2
#   Dunkel: 2
#   Sours: 2
#   Ales: 2
#   Wheat Ale: 1
#   Barley Wine: 1
#   Wild Ale: 1
#   British Ale: 1
#   Australian Ale: 1
#   Australian Lager: 1
#   Imperial Pale Ale: 1
#   California Common: 1
#   Whitbier: 1
#   Pale Ales: 1
#   Trappist: 1
#   Weizenbier: 1
#   Amber: 1
#   Bière de Garde: 1
#   Black IPA: 1
#   Blonde: 1
#   Farmhouse Ale: 1
#   Bière de Gardes: 1
#   Alt: 1
#   English IPA: 1
#   Dark Ale: 1
#   Bretts: 1
#   American Lager: 1
#   Cask Ale: 1
#   Strong Ale: 1
#   Weizenbock: 1
#   Marzen: 1
#   Specialty Ale: 1
#   Light Ale: 1
#   New England IPA: 1
#   Black Ale: 1
#   Brett: 1
#   American Lagers: 1
#   Blond Ale: 1
#   Weissbier: 1
#   India Pale Lager: 1
#   APA: 1
#   Bavarian Hefeweizen: 1
#   California Blonde Ale: 1
#   American Amber Ale: 1
#   Winter Ale: 1
#   Cream Ale: 1
#   American: 1
#   Belgian Wits: 1
#   European Lager: 1
#   Mexican Lager: 1
#   Strong Pale Ale: 1
#   XPA: 1
#
# Unique values and counts for column: tags
#   citrus: 36
#   spicy: 28
#   floral: 27
#   passion_fruit: 18
#   herbal: 17
#   pine: 15
#   fruity: 15
#   tropical_fruit: 14
#   noble: 13
#   earthy: 13
#   melon: 9
#   grassy: 9
#   grapefruit: 9
#   pineapple: 8
#   orange: 8
#   lemon: 7
#   peach: 6
#   tobacco: 6
#   black_pepper: 6
#   resin: 5
#   mild: 5
#   tangerine: 5
#   mint: 5
#   lavender: 5
#   sweet: 4
#   white_wine: 4
#   berry: 4
#   raspberry: 4
#   apricot: 4
#   gooseberry: 4
#   green_tea: 4
#   lime: 4
#   strawberry: 4
#   hay: 4
#   anise: 3
#   stone_fruit: 3
#   woody: 3
#   clove: 3
#   cherry: 3
#   leather: 3
#   caramel: 3
#   plum: 3
#   grapes: 3
#   blackberry: 3
#   lemongrass: 3
#   clean: 3
#   mandarin: 2
#   redcurrant: 2
#   oak: 2
#   hoppy: 2
#   lychee: 2
#   bitter: 2
#   oregano: 2
#   kumquat: 2
#   rose: 2
#   cognac: 2
#   pear: 2
#   mango: 2
#   tea: 2
#   pepper: 2
#   sauvignon_blanc: 2
#   nectar: 2
#   honeydew: 2
#   honey: 1
#   cannabis: 1
#   dank: 1
#   cedar: 1
#   bohemian: 1
#   spices: 1
#   allspice: 1
#   elderflower: 1
#   banana: 1
#   neutral: 1
#   licorice: 1
#   green: 1
#   sandalwood: 1
#   wine: 1
#   papaya: 1
#   lilac: 1
#   redberry: 1
#   incense: 1
#   sweet_fruit: 1
#   green_fruit: 1
#   jasmine: 1
#   black_currant: 1
#   fennel: 1
#   vanilla: 1
#   apple: 1
#   sugar: 1
#   smooth: 1
#   slightly_spicy: 1
#   menthol: 1
#   hibiscus: 1
#   black_tea: 1
#   red_berry: 1
#   dill: 1
#   dried_fruit: 1
#   mojito: 1
# After parsing columns:
# Shape: (100, 14)
#
# Columns: ['name', 'purpose', 'alpha_acid_avg', 'beta_acid_avg', 'alpha_beta_ratio', 'hsi', 'cohumulone_%_of_alpha', 'total_oils_avg', 'myrcene', 'humulene', 'caryophyllene', 'farnesene', 'tags', 'beer_styles']
#
# First 5 rows:
#       name purpose  alpha_acid_avg  beta_acid_avg  alpha_beta_ratio    hsi  \
# 0      NaN     NaN             NaN            NaN               NaN    NaN
# 1    Astra    Dual             8.5            5.0               1.5    NaN
# 2  Eclipse    Dual            17.4            7.5               1.5    NaN
# 3     Ella    Dual            16.3            5.9               2.0    NaN
# 4   Enigma   Aroma            16.5            5.8               2.0  0.295
#
#   cohumulone_%_of_alpha  total_oils_avg  myrcene  humulene  caryophyllene  \
# 0                   NaN             NaN      NaN       NaN            NaN
# 1               27% avg             2.0      NaN       7.0            2.5
# 2               35% avg             2.3     42.0       1.0            9.0
# 3             36.5% avg             2.9     42.0      18.5           11.5
# 4               40% avg             2.4     26.5      15.5            7.0
#
#    farnesene                                               tags  \
# 0        NaN                                                 []
# 1        NaN  [tropical_fruit, sweet, peach, white_wine, mel...
# 2        0.5                           [citrus, pine, mandarin]
# 3       13.0  [floral, spicy, grapefruit, tropical_fruit, no...
# 4       10.5  [tropical_fruit, berry, stone_fruit, raspberry...
#
#                                 beer_styles
# 0                                        []
# 1       [Ale, Pale Ale, IPA, Lager, Saison]
# 2  [IPA, Pale Ale, NEIPA, Lager, Wheat Ale]
# 3         [Pale Ale, Stout, Lager, Pilsner]
# 4                           [IPA, Pale Ale]
#
# 10 Random rows:
#                    name    purpose  alpha_acid_avg  beta_acid_avg  \
# 99          Pacific Gem  Bittering            14.0            8.0
# 7                 Helga      Aroma             6.4            6.0
# 71                Orion       Dual             7.5            4.1
# 15           Vic Secret       Dual            17.9            7.2
# 81           Tettnanger       Dual             4.2            4.1
# 29            Boomerang       Dual            12.0            7.5
# 35             Premiant  Bittering             8.0            5.0
# 89             Brooklyn       Dual            18.5            9.0
# 18     Canadian Redvine      Aroma             5.5            5.5
# 48  Tardif de Bourgogne      Aroma             3.8            4.5
#
#     alpha_beta_ratio   hsi cohumulone_%_of_alpha  total_oils_avg  myrcene  \
# 99               1.5  0.22             37.5% avg             1.2     35.0
# 7                1.0   NaN             21.5% avg             0.8      7.0
# 71               1.5   NaN             27.5% avg             1.5     48.5
# 15               2.0   NaN               54% avg             2.4     38.5
# 81               1.0   NaN               25% avg             0.8     40.5
# 29               1.5   NaN             29.5% avg             2.3     41.5
# 35               1.5   NaN             20.5% avg             1.5     42.5
# 89               1.5   NaN               26% avg             1.7      NaN
# 18               1.0  0.20               47% avg             NaN     70.0
# 48               1.0   NaN               20% avg             0.7      NaN
#
#     humulene  caryophyllene  farnesene  \
# 99      25.0            9.0        0.5
# 7       45.0           27.5        0.5
# 71      21.0            9.5        0.5
# 15      15.0           12.0        0.5
# 81      20.5            6.5       11.5
# 29      20.5            9.0        0.5
# 35      30.0           10.5        2.0
# 89       NaN            NaN        NaN
# 18       2.0            2.0        5.5
# 48       NaN            NaN        NaN
#
#                                                  tags  \
# 99  [black_pepper, berry, blackberry, floral, oak,...
# 7                                             [noble]
# 71                                            [spicy]
# 15  [tropical_fruit, pineapple, pine, passion_frui...
# 81                 [spicy, floral, pepper, black_tea]
# 29                                    [spicy, citrus]
# 35                                          [neutral]
# 89  [grapefruit, tropical_fruit, passion_fruit, sp...
# 18                  [cherry, berry, pine, grapefruit]
# 48  [floral, redberry, green_tea, noble, incense, ...
#
#                                           beer_styles
# 99                             [Pale Ale, IPA, Lager]
# 7                                        [Ale, Lager]
# 71       [German Ale, Lager, Helles, Dunkel, Pilsner]
# 15                     [Pale Ale, IPA, Stout, Porter]
# 81  [Wheat Beer, Bavarian Hefeweizen, Bitter, Cali...
# 29                                         [Ale, IPA]
# 35                              [Pilsner, Ale, Lager]
# 89                                                 []
# 18                                  [Red Ale, Porter]
# 48                                       [Ale, Lager]
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   92 non-null     object
#  1   purpose                92 non-null     object
#  2   alpha_acid_avg         92 non-null     float64
#  3   beta_acid_avg          88 non-null     float64
#  4   alpha_beta_ratio       84 non-null     float64
#  5   hsi                    12 non-null     object
#  6   cohumulone_%_of_alpha  84 non-null     object
#  7   total_oils_avg         87 non-null     float64
#  8   myrcene                72 non-null     float64
#  9   humulene               70 non-null     float64
#  10  caryophyllene          69 non-null     float64
#  11  farnesene              68 non-null     float64
#  12  tags                   100 non-null    object
#  13  beer_styles            100 non-null    object
# dtypes: float64(8), object(6)
# memory usage: 11.1+ KB
# None
#
# Describe:
#          name purpose  alpha_acid_avg  beta_acid_avg  alpha_beta_ratio    hsi  \
# count      92      92       92.000000       88.00000         84.000000     12
# unique     92       3             NaN            NaN               NaN     12
# top     Astra   Aroma             NaN            NaN               NaN  0.295
# freq        1      47             NaN            NaN               NaN      1
# mean      NaN     NaN        8.761957        5.67500          1.380952    NaN
# std       NaN     NaN        4.372085        1.63758          0.392851    NaN
# min       NaN     NaN        2.200000        2.90000          0.500000    NaN
# 25%       NaN     NaN        5.775000        4.50000          1.000000    NaN
# 50%       NaN     NaN        7.500000        5.50000          1.500000    NaN
# 75%       NaN     NaN       11.625000        6.57500          1.500000    NaN
# max       NaN     NaN       20.500000       12.50000          2.500000    NaN
#
#        cohumulone_%_of_alpha  total_oils_avg    myrcene   humulene  \
# count                     84       87.000000  72.000000  70.000000
# unique                    46             NaN        NaN        NaN
# top                37.5% avg             NaN        NaN        NaN
# freq                       5             NaN        NaN        NaN
# mean                     NaN        1.539080  40.944444  20.478571
# std                      NaN        0.719715  12.851962  12.832939
# min                      NaN        0.600000   7.000000   1.000000
# 25%                      NaN        1.050000  32.500000  12.125000
# 50%                      NaN        1.400000  39.750000  20.000000
# 75%                      NaN        1.800000  47.750000  29.625000
# max                      NaN        4.500000  70.000000  55.500000
#
#         caryophyllene  farnesene tags beer_styles
# count       69.000000  68.000000  100         100
# unique            NaN        NaN   89          72
# top               NaN        NaN   []          []
# freq              NaN        NaN   12          23
# mean         8.753623   3.136765  NaN         NaN
# std          4.522512   5.372564  NaN         NaN
# min          1.000000   0.500000  NaN         NaN
# 25%          6.500000   0.500000  NaN         NaN
# 50%          9.000000   0.500000  NaN         NaN
# 75%         10.500000   2.250000  NaN         NaN
# max         27.500000  25.000000  NaN         NaN
#
# Missing values per column:
# name                      8
# purpose                   8
# alpha_acid_avg            8
# beta_acid_avg            12
# alpha_beta_ratio         16
# hsi                      88
# cohumulone_%_of_alpha    16
# total_oils_avg           13
# myrcene                  28
# humulene                 30
# caryophyllene            31
# farnesene                32
# tags                      0
# beer_styles               0
# dtype: int64
# Data exported to: processed_hop_data.parquet (Parquet format)
# Data exported to: processed_hop_data.csv (CSV format — lists saved as strings)

# %% [markdown]
# Very high missing values: 'hsi'
# High missing values: 'myrcene', 'humulene', 'caryophyllene', 'farnesene'
